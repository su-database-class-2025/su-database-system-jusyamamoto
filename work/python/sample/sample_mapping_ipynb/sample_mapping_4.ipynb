# %% [markdown]
# # SQL for accessing spatial data on postgreSQL

# %% [markdown]
# データベースシステム講義資料
# version 0.0.1
# authors: H. Chenan & N. Tsutsumida
#
# Copyright (c) 2023 Narumasa Tsutsumida
# Released under the MIT license
# https://opensource.org/licenses/mit-license.php

# %% [markdown]
# ## Task

# %% [markdown]
# さいたま市内のコンビニを抽出し地図化する

# %% [markdown]
# ## prerequisites

# %%
import os
from sqlalchemy import create_engine
import pandas as pd
import geopandas as gpd
import numpy as np
import folium
pd.set_option('display.max_columns', 100)

# %%
def query_geopandas(sql, db):
    """
    Executes a SQL query on a postGIS and returns the result as a GeoPandas GeoDataFrame.

    Args:
        sql (str): The SQL query to execute.
        db (str): The name of the PostgreSQL database to connect to.

    Returns:
        geopandas.GeoDataFrame: The result of the SQL query as a GeoPandas GeoDataFrame.
    """
    DATABASE_URL = 'postgresql://postgres:postgres@postgis_container:5432/{}'.format(db)
    conn = create_engine(DATABASE_URL)
    query_result_gdf = gpd.GeoDataFrame.from_postgis(
        sql, conn, geom_col='way') #geom_col='way' when using osm_kanto, geom_col='geom' when using gisdb
    return query_result_gdf

# %% [markdown]
# ## Define a sql command

# %%
sql = """
    select pt.*
    from planet_osm_point pt, adm2 poly
    where pt.amenity='place_of_worship' and
    name_2 = 'Saitama' and
    st_within(pt.way,st_transform(poly.geom, 3857));
    """

# %% [markdown]
# ## Outputs

# %%
def display_interactive_map(gdf):
    if gdf.crs != 'EPSG:4326':
        gdf = gdf.to_crs(epsg=4326)
    # Create a base map
    m = folium.Map(location=[35.9, 139.6455], zoom_start=12)  # You can modify the location as per your dataset

    # Add data points to the map
    for _, row in gdf.iterrows():
        coords = (row['way'].y, row['way'].x)
        folium.Marker(location=coords, popup=row['name']).add_to(m)

    return m

# %%
out = query_geopandas(sql,'gisdb')
map_display = display_interactive_map(out)
print(out)
display(map_display)
# Out:
#           osm_id access addr:housename addr:housenumber addr:interpolation  \
# 0    11296171889   None           None             None               None
# 1    11897313050   None           None             None               None
# 2    12457221550   None           None             None               None
# 3     7775953029   None           None             None               None
# 4    12532125599   None           None             None               None
# ..           ...    ...            ...              ...                ...
# 184  12877612291   None           None             None               None
# 185  12861340303   None           None             None               None
# 186   9149671042   None           None             None               None
# 187   8386058509   None           None             None               None
# 188   4825536432   None           None             None               None
#
#     admin_level aerialway aeroway           amenity  area barrier bicycle  \
# 0          None      None    None  place_of_worship  None    None    None
# 1          None      None    None  place_of_worship  None    None    None
# 2          None      None    None  place_of_worship  None    None    None
# 3          None      None    None  place_of_worship  None    None    None
# 4          None      None    None  place_of_worship  None    None    None
# ..          ...       ...     ...               ...   ...     ...     ...
# 184        None      None    None  place_of_worship  None    None    None
# 185        None      None    None  place_of_worship  None    None    None
# 186        None      None    None  place_of_worship  None    None    None
# 187        None      None    None  place_of_worship  None    None    None
# 188        None      None    None  place_of_worship  None    None    None
#
#     brand bridge boundary building capital construction covered culvert  \
# 0    None   None     None     None    None         None    None    None
# 1    None   None     None     None    None         None    None    None
# 2    None   None     None     None    None         None    None    None
# 3    None   None     None     None    None         None    None    None
# 4    None   None     None     None    None         None    None    None
# ..    ...    ...      ...      ...     ...          ...     ...     ...
# 184  None   None     None     None    None         None    None    None
# 185  None   None     None     None    None         None    None    None
# 186  None   None     None     None    None         None    None    None
# 187  None   None     None     None    None         None    None    None
# 188  None   None     None     None    None         None    None    None
#
#     cutting denomination disused   ele embankment  foot generator:source  \
# 0      None         None    None  None       None  None             None
# 1      None         None    None  None       None  None             None
# 2      None         None    None  None       None  None             None
# 3      None         None    None  None       None  None             None
# 4      None         None    None  None       None  None             None
# ..      ...          ...     ...   ...        ...   ...              ...
# 184    None         None    None  None       None  None             None
# 185    None         None    None  None       None  None             None
# 186    None         None    None  None       None  None             None
# 187    None         None    None  None       None  None             None
# 188    None         None    None  None       None  None             None
#
#     harbour highway historic horse intermittent junction landuse layer  \
# 0      None    None     None  None         None     None    None  None
# 1      None    None     None  None         None     None    None  None
# 2      None    None     None  None         None     None    None  None
# 3      None    None     None  None         None     None    None  None
# 4      None    None     None  None         None     None    None  None
# ..      ...     ...      ...   ...          ...      ...     ...   ...
# 184    None    None     None  None         None     None    None  None
# 185    None    None     None  None         None     None    None  None
# 186    None    None     None  None         None     None    None  None
# 187    None    None     None  None         None     None    None  None
# 188    None    None     None  None         None     None    None  None
#
#     leisure  lock man_made military motorcar              name natural office  \
# 0      None  None     None     None     None              愛宕神社    None   None
# 1      None  None     None     None     None               清浄院    None   None
# 2      None  None     None     None     None               吉祥院    None   None
# 3      None  None     None     None     None               高林寺    None   None
# 4      None  None     None     None     None               真福寺    None   None
# ..      ...   ...      ...      ...      ...               ...     ...    ...
# 184    None  None     None     None     None              前地薬師    None   None
# 185    None  None     None     None     None  日本ナザレン教団浦和キリスト教会    None   None
# 186    None  None     None     None     None               和光院    None   None
# 187    None  None     None     None     None               八幡社    None   None
# 188    None  None     None     None     None              白幡観音    None   None
#
#     oneway operator place   poi population power power_source  \
# 0     None     None  None  None       None  None         None
# 1     None     None  None  None       None  None         None
# 2     None     None  None  None       None  None         None
# 3     None     None  None  None       None  None         None
# 4     None     None  None  None       None  None         None
# ..     ...      ...   ...   ...        ...   ...          ...
# 184   None     None  None  None       None  None         None
# 185   None     None  None  None       None  None         None
# 186   None     None  None  None       None  None         None
# 187   None     None  None  None       None  None         None
# 188   None     None  None  None       None  None         None
#
#     public_transport railway   ref   religion route service  shop sport  \
# 0               None    None  None     shinto  None    None  None  None
# 1               None    None  None   buddhist  None    None  None  None
# 2               None    None  None   buddhist  None    None  None  None
# 3               None    None  None   buddhist  None    None  None  None
# 4               None    None  None   buddhist  None    None  None  None
# ..               ...     ...   ...        ...   ...     ...   ...   ...
# 184             None    None  None   buddhist  None    None  None  None
# 185             None    None  None  christian  None    None  None  None
# 186             None    None  None   buddhist  None    None  None  None
# 187             None    None  None     shinto  None    None  None  None
# 188             None    None  None   buddhist  None    None  None  None
#
#     surface  toll tourism tower:type tunnel water waterway wetland width  \
# 0      None  None    None       None   None  None     None    None  None
# 1      None  None    None       None   None  None     None    None  None
# 2      None  None    None       None   None  None     None    None  None
# 3      None  None    None       None   None  None     None    None  None
# 4      None  None    None       None   None  None     None    None  None
# ..      ...   ...     ...        ...    ...   ...      ...     ...   ...
# 184    None  None    None       None   None  None     None    None  None
# 185    None  None    None       None   None  None     None    None  None
# 186    None  None    None       None   None  None     None    None  None
# 187    None  None    None       None   None  None     None    None  None
# 188    None  None    None       None   None  None     None    None  None
#
#      wood z_order                               way
# 0    None    None  POINT (15537891.959 4293145.333)
# 1    None    None  POINT (15541816.472 4293946.432)
# 2    None    None   POINT (15541668.64 4292954.576)
# 3    None    None  POINT (15543130.666 4292913.477)
# 4    None    None  POINT (15542555.322 4294052.112)
# ..    ...     ...                               ...
# 184  None    None  POINT (15547396.451 4280857.491)
# 185  None    None  POINT (15547760.243 4281142.452)
# 186  None    None  POINT (15546630.706 4278445.657)
# 187  None    None  POINT (15544457.026 4279400.445)
# 188  None    None  POINT (15546211.856 4279053.664)
#
# [189 rows x 70 columns]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a901eba4b5712cca8631c077cc66b398 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a901eba4b5712cca8631c077cc66b398&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a901eba4b5712cca8631c077cc66b398 = L.map(
#                 &quot;map_a901eba4b5712cca8631c077cc66b398&quot;,
#                 {
#                     center: [35.9, 139.6455],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9e7028603f620be2256baa88841f6e08 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9e7028603f620be2256baa88841f6e08.addTo(map_a901eba4b5712cca8631c077cc66b398);
#
#
#             var marker_e6058ce5b4a8c3e76fb427772f4a92c1 = L.marker(
#                 [35.945648999730174, 139.5792583],
#                 {
# }
#             ).addTo(map_a901eba4b5712cca8631c077cc66b398);
#
#
#         var popup_00e3a6f0b42d4e56c701a48cd7d5fa18 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_898b2080c90c42f668d17832242dd10d = $(`&lt;div id=&quot;html_898b2080c90c42f668d17832242dd10d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;愛宕神社&lt;/div&gt;`)[0];
#                 popup_00e3a6f0b42d4e56c701a48cd7d5fa18.setContent(html_898b2080c90c42f668d17832242dd10d);
#
#
#
#         marker_e6058ce5b4a8c3e76fb427772f4a92c1.bindPopup(popup_00e3a6f0b42d4e56c701a48cd7d5fa18)
#         ;
#
#
#
#
#             var marker_218bb95ca8922c6e95fdb1ef6e5dfd28 = L.marker(
#                 [35.951474799730754, 139.61451279999997],
#                 {
# }
#             ).addTo(map_a901eba4b5712cca8631c077cc66b398);
#
#
#         var popup_f9e106a52a5b6634c01ec7a49d0a630b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_371d33ad40764ca531d0d051ebfeb9f9 = $(`&lt;div id=&quot;html_371d33ad40764ca531d0d051ebfeb9f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;清浄院&lt;/div&gt;`)[0];
#                 popup_f9e106a52a5b6634c01ec7a49d0a630b.setContent(html_371d33ad40764ca531d0d051ebfeb9f9);
#
#
#
#         marker_218bb95ca8922c6e95fdb1ef6e5dfd28.bindPopup(popup_f9e106a52a5b6634c01ec7a49d0a630b)
#         ;
#
#
#
#
#             var marker_6ff9d325b4f250058b9bbd778ec37aab = L.marker(
#                 [35.94426169973005, 139.61318479999997],
#                 {
# }
#             ).addTo(map_a901eba4b5712cca8631c077cc66b398);
#
#
#         var popup_c36673f52957366a255a55e3885b37db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7cd3abe0347a8be90f8a1fc086229814 = $(`&lt;div id=&quot;html_7cd3abe0347a8be90f8a1fc086229814&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;吉祥院&lt;/div&gt;`)[0];
#                 popup_c36673f52957366a255a55e3885b37db.setContent(html_7cd3abe0347a8be90f8a1fc086229814);
#
#
#
#         marker_6ff9d325b4f250058b9bbd778ec37aab.bindPopup(popup_c36673f52957366a255a55e3885b37db)
#         ;
#
#
#
#
#             var marker_887c0f6779eafbd338a239ec64382f85 = L.marker(
#                 [35.943962799730016, 139.6263184],
#                 {
# }
#             ).addTo(map_a901eba4b5712cca8631c077cc66b398);
#
#
#         var popup_cc327b8cb6ddd09fb015a5f9cbe93855 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d079eae5df140807e18c15c6635db8a1 = $(`&lt;div id=&quot;html_d079eae5df140807e18c15c6635db8a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;高林寺&lt;/div&gt;`)[0];
#                 popup_cc327b8cb6ddd09fb015a5f9cbe93855.setContent(html_d079eae5df140807e18c15c6635db8a1);
#
#
#
#         marker_887c0f6779eafbd338a239ec64382f85.bindPopup(popup_cc327b8cb6ddd09fb015a5f9cbe93855)
#         ;
#
#
#
#
#             var marker_a674e65d0aa0a2523d7649d2e29a3493 = L.marker(
#                 [35.952243299730824, 139.62115],
#                 {
# }
#             ).addTo(map_a901eba4b5712cca8631c077cc66b398);
#
#
#         var popup_1d95855d3e38a3a28f3973e979040d8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49db1c8e50ff223a916d22bbbe84057e = $(`&lt;div id=&quot;html_49db1c8e50ff223a916d22bbbe84057e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;真福寺&lt;/div&gt;`)[0];
#                 popup_1d95855d3e38a3a28f3973e979040d8e.setContent(html_49db1c8e50ff223a916d22bbbe84057e);
#
#
#
#         marker_a674e65d0aa0a2523d7649d2e29a3493.bindPopup(popup_1d95855d3e38a3a28f3973e979040d8e)
#         ;
#
#
#
#
#             var marker_a3223d5ba6fef70cddd23bd8fb42b22d = L.marker(
#                 [35.94306149972992, 139.6417
